# %%
import pandas as pd

df = pd.read_csv("incident_estimates.csv")
df.style.set_properties(**{
    'text-align': 'left',
    'white-space': 'pre-wrap'
}).set_table_styles([
    {'selector': 'th', 'props': [('text-align', 'left')]}
])
# Out:
# <style type="text/css">
# #T_ce40e th {
#   text-align: left;
# }
# #T_ce40e_row0_col0, #T_ce40e_row0_col1, #T_ce40e_row0_col2, #T_ce40e_row0_col3, #T_ce40e_row0_col4, #T_ce40e_row0_col5, #T_ce40e_row0_col6, #T_ce40e_row0_col7, #T_ce40e_row0_col8, #T_ce40e_row0_col9, #T_ce40e_row0_col10, #T_ce40e_row0_col11, #T_ce40e_row1_col0, #T_ce40e_row1_col1, #T_ce40e_row1_col2, #T_ce40e_row1_col3, #T_ce40e_row1_col4, #T_ce40e_row1_col5, #T_ce40e_row1_col6, #T_ce40e_row1_col7, #T_ce40e_row1_col8, #T_ce40e_row1_col9, #T_ce40e_row1_col10, #T_ce40e_row1_col11, #T_ce40e_row2_col0, #T_ce40e_row2_col1, #T_ce40e_row2_col2, #T_ce40e_row2_col3, #T_ce40e_row2_col4, #T_ce40e_row2_col5, #T_ce40e_row2_col6, #T_ce40e_row2_col7, #T_ce40e_row2_col8, #T_ce40e_row2_col9, #T_ce40e_row2_col10, #T_ce40e_row2_col11, #T_ce40e_row3_col0, #T_ce40e_row3_col1, #T_ce40e_row3_col2, #T_ce40e_row3_col3, #T_ce40e_row3_col4, #T_ce40e_row3_col5, #T_ce40e_row3_col6, #T_ce40e_row3_col7, #T_ce40e_row3_col8, #T_ce40e_row3_col9, #T_ce40e_row3_col10, #T_ce40e_row3_col11, #T_ce40e_row4_col0, #T_ce40e_row4_col1, #T_ce40e_row4_col2, #T_ce40e_row4_col3, #T_ce40e_row4_col4, #T_ce40e_row4_col5, #T_ce40e_row4_col6, #T_ce40e_row4_col7, #T_ce40e_row4_col8, #T_ce40e_row4_col9, #T_ce40e_row4_col10, #T_ce40e_row4_col11, #T_ce40e_row5_col0, #T_ce40e_row5_col1, #T_ce40e_row5_col2, #T_ce40e_row5_col3, #T_ce40e_row5_col4, #T_ce40e_row5_col5, #T_ce40e_row5_col6, #T_ce40e_row5_col7, #T_ce40e_row5_col8, #T_ce40e_row5_col9, #T_ce40e_row5_col10, #T_ce40e_row5_col11, #T_ce40e_row6_col0, #T_ce40e_row6_col1, #T_ce40e_row6_col2, #T_ce40e_row6_col3, #T_ce40e_row6_col4, #T_ce40e_row6_col5, #T_ce40e_row6_col6, #T_ce40e_row6_col7, #T_ce40e_row6_col8, #T_ce40e_row6_col9, #T_ce40e_row6_col10, #T_ce40e_row6_col11, #T_ce40e_row7_col0, #T_ce40e_row7_col1, #T_ce40e_row7_col2, #T_ce40e_row7_col3, #T_ce40e_row7_col4, #T_ce40e_row7_col5, #T_ce40e_row7_col6, #T_ce40e_row7_col7, #T_ce40e_row7_col8, #T_ce40e_row7_col9, #T_ce40e_row7_col10, #T_ce40e_row7_col11, #T_ce40e_row8_col0, #T_ce40e_row8_col1, #T_ce40e_row8_col2, #T_ce40e_row8_col3, #T_ce40e_row8_col4, #T_ce40e_row8_col5, #T_ce40e_row8_col6, #T_ce40e_row8_col7, #T_ce40e_row8_col8, #T_ce40e_row8_col9, #T_ce40e_row8_col10, #T_ce40e_row8_col11, #T_ce40e_row9_col0, #T_ce40e_row9_col1, #T_ce40e_row9_col2, #T_ce40e_row9_col3, #T_ce40e_row9_col4, #T_ce40e_row9_col5, #T_ce40e_row9_col6, #T_ce40e_row9_col7, #T_ce40e_row9_col8, #T_ce40e_row9_col9, #T_ce40e_row9_col10, #T_ce40e_row9_col11, #T_ce40e_row10_col0, #T_ce40e_row10_col1, #T_ce40e_row10_col2, #T_ce40e_row10_col3, #T_ce40e_row10_col4, #T_ce40e_row10_col5, #T_ce40e_row10_col6, #T_ce40e_row10_col7, #T_ce40e_row10_col8, #T_ce40e_row10_col9, #T_ce40e_row10_col10, #T_ce40e_row10_col11, #T_ce40e_row11_col0, #T_ce40e_row11_col1, #T_ce40e_row11_col2, #T_ce40e_row11_col3, #T_ce40e_row11_col4, #T_ce40e_row11_col5, #T_ce40e_row11_col6, #T_ce40e_row11_col7, #T_ce40e_row11_col8, #T_ce40e_row11_col9, #T_ce40e_row11_col10, #T_ce40e_row11_col11, #T_ce40e_row12_col0, #T_ce40e_row12_col1, #T_ce40e_row12_col2, #T_ce40e_row12_col3, #T_ce40e_row12_col4, #T_ce40e_row12_col5, #T_ce40e_row12_col6, #T_ce40e_row12_col7, #T_ce40e_row12_col8, #T_ce40e_row12_col9, #T_ce40e_row12_col10, #T_ce40e_row12_col11, #T_ce40e_row13_col0, #T_ce40e_row13_col1, #T_ce40e_row13_col2, #T_ce40e_row13_col3, #T_ce40e_row13_col4, #T_ce40e_row13_col5, #T_ce40e_row13_col6, #T_ce40e_row13_col7, #T_ce40e_row13_col8, #T_ce40e_row13_col9, #T_ce40e_row13_col10, #T_ce40e_row13_col11, #T_ce40e_row14_col0, #T_ce40e_row14_col1, #T_ce40e_row14_col2, #T_ce40e_row14_col3, #T_ce40e_row14_col4, #T_ce40e_row14_col5, #T_ce40e_row14_col6, #T_ce40e_row14_col7, #T_ce40e_row14_col8, #T_ce40e_row14_col9, #T_ce40e_row14_col10, #T_ce40e_row14_col11 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_ce40e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce40e_level0_col0" class="col_heading level0 col0" >incident_id</th>
#       <th id="T_ce40e_level0_col1" class="col_heading level0 col1" >start_time</th>
#       <th id="T_ce40e_level0_col2" class="col_heading level0 col2" >end_time</th>
#       <th id="T_ce40e_level0_col3" class="col_heading level0 col3" >affected_services</th>
#       <th id="T_ce40e_level0_col4" class="col_heading level0 col4" >traffic</th>
#       <th id="T_ce40e_level0_col5" class="col_heading level0 col5" >user_sessions</th>
#       <th id="T_ce40e_level0_col6" class="col_heading level0 col6" >severity</th>
#       <th id="T_ce40e_level0_col7" class="col_heading level0 col7" >root_cause</th>
#       <th id="T_ce40e_level0_col8" class="col_heading level0 col8" >resolution_time</th>
#       <th id="T_ce40e_level0_col9" class="col_heading level0 col9" >predicted_sessions_affected</th>
#       <th id="T_ce40e_level0_col10" class="col_heading level0 col10" >predicted_revenue_loss</th>
#       <th id="T_ce40e_level0_col11" class="col_heading level0 col11" >business_impact_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce40e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce40e_row0_col0" class="data row0 col0" >SYN001</td>
#       <td id="T_ce40e_row0_col1" class="data row0 col1" >2025-09-05T10:00</td>
#       <td id="T_ce40e_row0_col2" class="data row0 col2" >2025-09-05T10:20</td>
#       <td id="T_ce40e_row0_col3" class="data row0 col3" >checkout</td>
#       <td id="T_ce40e_row0_col4" class="data row0 col4" >15000</td>
#       <td id="T_ce40e_row0_col5" class="data row0 col5" >12000</td>
#       <td id="T_ce40e_row0_col6" class="data row0 col6" >major</td>
#       <td id="T_ce40e_row0_col7" class="data row0 col7" >Cache server restart</td>
#       <td id="T_ce40e_row0_col8" class="data row0 col8" >20</td>
#       <td id="T_ce40e_row0_col9" class="data row0 col9" >2960</td>
#       <td id="T_ce40e_row0_col10" class="data row0 col10" >3681</td>
#       <td id="T_ce40e_row0_col11" class="data row0 col11" >"Incident SYN001 occurred between 2025-09-05T10:00 and 2025-09-05T10:20, affecting the checkout service with approximately 15,000 users and 12,000 sessions impacted. The root cause was a Cache server restart, which was resolved in 20 minutes. According to estimated impact, this incident resulted in 2960 lost sessions and $3681 in potential revenue loss. This highlights the importance of resilient infrastructure and rapid recovery protocols to minimize the effects of such incidents."</td>
#     </tr>
#     <tr>
#       <th id="T_ce40e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce40e_row1_col0" class="data row1 col0" >SYN002</td>
#       <td id="T_ce40e_row1_col1" class="data row1 col1" >2025-09-05T11:00</td>
#       <td id="T_ce40e_row1_col2" class="data row1 col2" >2025-09-05T11:30</td>
#       <td id="T_ce40e_row1_col3" class="data row1 col3" >login</td>
#       <td id="T_ce40e_row1_col4" class="data row1 col4" >9000</td>
#       <td id="T_ce40e_row1_col5" class="data row1 col5" >7000</td>
#       <td id="T_ce40e_row1_col6" class="data row1 col6" >minor</td>
#       <td id="T_ce40e_row1_col7" class="data row1 col7" >Config update</td>
#       <td id="T_ce40e_row1_col8" class="data row1 col8" >30</td>
#       <td id="T_ce40e_row1_col9" class="data row1 col9" >1022</td>
#       <td id="T_ce40e_row1_col10" class="data row1 col10" >1462</td>
#       <td id="T_ce40e_row1_col11" class="data row1 col11" >Incident SYN002 occurred between 2025-09-05T11:00 and 2025-09-05T11:30, affecting the login service. Approximately 9000 users and 7000 sessions were impacted due to a minor severity incident. The root cause was identified as a config update, which was resolved within 30 minutes. According to estimated impact analysis, 1022 lost sessions and $1462 in potential revenue loss occurred. This incident emphasizes the significance of resilient infrastructure and rapid recovery procedures to minimize the effects of such incidents on the organization's operations and revenue.</td>
#     </tr>
#     <tr>
#       <th id="T_ce40e_level0_row2" class="row_heading level0 row2" >2
